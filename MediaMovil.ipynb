# %% [markdown]
# <a href="https://colab.research.google.com/github/SantiData87/yFinance/blob/main/MediaMovil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Descargar datos de GGAL (Grupo Financiero Galicia) de los últimos 6 meses
ticker = 'GGAL.BA'
data = yf.download(ticker, period='10y')

# Calcular la media móvil simple (SMA) de 21 ruedas
data['SMA_21'] = data['Close'].rolling(window=21).mean()

# Graficar la curva de precios y la SMA de 21 ruedas
plt.figure(figsize=(14, 7))
plt.plot(data['Close'], label='Precio de Cierre')
plt.plot(data['SMA_21'], label='Media Simple de 21 ruedas', color='orange')
plt.title(f'Curva de Precios y Media Simple de 21 ruedas para {ticker}')
plt.xlabel('Fecha')
plt.ylabel('Precio (ARS)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

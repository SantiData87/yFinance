# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Cargo Archivo

# %%
df= pd.read_csv('C:/Users/Sofia Medici/Desktop/DATA - Programas/Py Notebooks/DE_S6/Titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # Indexar con

# %% [markdown]
# ## [] o [[]]

# %%
df['Name']  # Cuando quiero seleccionar UNA SOLA columna necesito un solo corchete []. Me arroja un DataSeries
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df[['Name','Sex']] #Cuando quiero seleccionar mas de una columna necesito doble [[]]. Me arroja un DataFrame
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
# [891 rows x 2 columns]

# %% [markdown]
# ## == != ><

# %%
df['Fare']>250 #Me devuelve Booleano: True or False
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df[df['Fare']>250] #Me devuelve un DataFrame
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %% [markdown]
# ## .loc

# %%
df.loc[:,['Name', 'Sex']] #Todas las filas y columnas Name y Sex
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
# [891 rows x 2 columns]

# %% [markdown]
# ## .iloc
# (Row, Column)
# El primer numero es tenido en cuenta y el segundo no
# Empieza a contar desde CERO la primer columna que no es el index

# %%
df.iloc[:,3:5] #Todas las filas y columnas de la 3 a la 4 incluida (la 5 es extremo no la devuelve)
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
# [891 rows x 2 columns]

# %% [markdown]
# # .isin()

# %%
df[df['Pclass'].isin([1,2])]

# %%
#Otra posibilidad es usando OR: |
df[(df['Pclass'] == 1) | (df['Pclass'] == 2)]

# %% [markdown]
# # Creo Columna

# %%
df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df['Fare']*1050
# Out:
# 0       7612.500
# 1      74847.465
# 2       8321.250
# 3      55755.000
# 4       8452.500
#          ...
# 886    13650.000
# 887    31500.000
# 888    24622.500
# 889    31500.000
# 890     8137.500
# Name: Fare, Length: 891, dtype: float64

# %%
df['Fare_Pesos'] = df['Fare']*1050

# %% [markdown]
# ## def + .apply
# Defino Funcion utilizando if
# En este caso aumento en un 20% la columna Fare a quienes son de clase 1

# %%
def pay_if_reach(x):
  if x['Pclass'] == 1:
    return x['Fare'] * 1.2
  else:
    return x['Fare']

# %%
df['Fare_for_reach'] = df.apply(pay_if_reach, axis=1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## lambda + apply
# Son funciones anonimas porque no tienene nombre.
# La funcion solo vive en la linea de codigo utlizada y no puede ser "llamada" de nuevo

# %%
df['Fare_for_reach_2'] = df.apply(lambda x: x['Fare'] * 1.2 if x['Pclass'] == 1 else x['Fare'] , axis=1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Merge
# Es lo mismo que JOIN en SQL

# %%
# Creao un DataFrame
df_class = pd.DataFrame({'Pclass': [1,2,3], 'Clase' : ['Alta', 'Media', 'Baja']})
df_class
# Out:
#    Pclass  Clase
# 0       1   Alta
# 1       2  Media
# 2       3   Baja

# %%
# Left significa que tra TODOS los registros de 'df' y solo los de 'df_class? en donde coincide la columna 'Pclass'
df_merge = df.merge(df_class, how='left', on='Pclass')
df_merge
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### a

# %%
# Creao un DataFrame
df_clase = pd.DataFrame({'NClase': [1,2,3], 'Clase' : ['Alta', 'Media', 'Baja']})
df_clase
# Out:
#    NClase  Clase
# 0       1   Alta
# 1       2  Media
# 2       3   Baja

# %%
# Si tuvieran distinto nombre las columnas con las cual uno los df
df_merge2 = df.merge(df_clase, how='left', left_on='Pclass' , right_on='NClase')
df_merge2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Agregacion

# %% [markdown]
# ## .groupby()

# %% [markdown]
# ### .count()

# %%
#Es importante que PassengerId no tenga NULOS
#SQL seria: SELEC SEX , COUNT(PassengerId) FROM DF BY SEX
df.groupby(['Sex']).PassengerId.count()
# Out:
# Sex
# female    314
# male      577
# Name: PassengerId, dtype: int64

# %% [markdown]
# ### .mean()

# %%
#Cuanto pago en promedio cada clase
df_merge.groupby(['Clase']).Fare.mean()
# Out:
# Clase
# Alta     100.985625
# Baja      13.675550
# Media     20.662183
# Name: Fare_for_reach_2, dtype: float64

# %%
df_merge.groupby(['Clase']).Fare_for_reach_2.mean()
# Out:
# Clase
# Alta     100.985625
# Baja      13.675550
# Media     20.662183
# Name: Fare_for_reach_2, dtype: float64

# %%
df_merge.groupby(['Clase','Sex']).Fare_for_reach_2.mean()
# Out:
# Clase  Sex
# Alta   female    127.350957
#        male       80.671352
# Baja   female     16.118810
#        male       12.661633
# Media  female     21.970121
#        male       19.741782
# Name: Fare_for_reach_2, dtype: float64

# %%
df_merge.groupby(['Clase','Sex'])['Fare_for_reach_2'].mean()
# Out:
# Clase  Sex
# Alta   female    127.350957
#        male       80.671352
# Baja   female     16.118810
#        male       12.661633
# Media  female     21.970121
#        male       19.741782
# Name: Fare_for_reach_2, dtype: float64

# %%
df_merge.groupby(['Clase'])[['Fare_for_reach_2','Age']].mean()
# Out:
#        Fare_for_reach_2        Age
# Clase
# Alta         100.985625  38.233441
# Baja          13.675550  25.140620
# Media         20.662183  29.877630

# %%
df_merge.groupby(['Clase', 'Sex'])[['Fare_for_reach_2','Age']].mean()
# Out:
#               Fare_for_reach_2        Age
# Clase Sex
# Alta  female        127.350957  34.611765
#       male           80.671352  41.281386
# Baja  female         16.118810  21.750000
#       male           12.661633  26.507589
# Media female         21.970121  28.722973
#       male           19.741782  30.740707

# %% [markdown]
# ### .max()

# %%
df_merge.groupby(['Clase']).Fare_for_reach_2.max()
# Out:
# Clase
# Alta     614.79504
# Baja      69.55000
# Media     73.50000
# Name: Fare_for_reach_2, dtype: float64

# %%
df_merge.groupby(['Clase']).Fare.max()
# Out:
# Clase
# Alta     512.3292
# Baja      69.5500
# Media     73.5000
# Name: Fare, dtype: float64

# %%
#Persona mas vieja del titanic
df['Age'].max()
# Out:
# 80.0

# %%
#Persona mas joven del titanic: un bebe
df['Age'].min()
# Out:
# 0.42

# %%
# Out:
# Clase  Sex
# Alta   female    512.3292
#        male      512.3292
# Baja   female     69.5500
#        male       69.5500
# Media  female     65.0000
#        male       73.5000
# Name: Fare, dtype: float64
